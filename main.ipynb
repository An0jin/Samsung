# %%
# %pip install pandas numpy matplotlib scikit-learn openpyxl koreanize-matplotlib seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
df = pd.read_excel('./SamSung.xlsx')
df
# Out:
#          날짜      외국인     보유율       기관       개인     종가       전일비       거래량
# 0    08.08.  2295222  0.5059   937140 -4186201  71800  13001300  21722999
# 1    08.07.  -389000  0.5055   614600 -1176932  70500  17001700  15008213
# 2    08.06.  -611525  0.5055  -945597   767674  68800  11001100  12542415
# 3    08.05. -2543870  0.5056   104329  1433127  69900    200200  14392903
# 4    08.04.  -471827  0.5061  -934749   535317  69700    800800  14780072
# ..      ...      ...     ...      ...      ...    ...       ...       ...
# 300  05.16. -3786158  0.5596  1856645  1875126  78200    100100  20989778
# 301  05.14.  -393521  0.5600    64598   326338  78300    100100  11763992
# 302  05.13.  -960230  0.5601 -1674382  2712543  78400    800800  18652344
# 303  05.10.   618165  0.5602 -2037692  1400346  79200    500500  16976124
# 304  05.09. -1232345  0.5601    24866  1046243  79700  16001600  18759935
#
# [305 rows x 8 columns]

# %%
df['전일비']=df['전일비'].astype(str)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 305 entries, 0 to 304
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   날짜      305 non-null    object
#  1   외국인     305 non-null    int64
#  2   보유율     305 non-null    float64
#  3   기관      305 non-null    int64
#  4   개인      305 non-null    int64
#  5   종가      305 non-null    int64
#  6   전일비     305 non-null    object
#  7   거래량     305 non-null    int64
# dtypes: float64(1), int64(5), object(2)
# memory usage: 19.2+ KB

# %%
df['전일비']=df['전일비'].apply(lambda x: x[:int(len(x)/2)])
df
# Out:
#          날짜      외국인     보유율       기관       개인     종가   전일비       거래량
# 0    08.08.  2295222  0.5059   937140 -4186201  71800  1300  21722999
# 1    08.07.  -389000  0.5055   614600 -1176932  70500  1700  15008213
# 2    08.06.  -611525  0.5055  -945597   767674  68800  1100  12542415
# 3    08.05. -2543870  0.5056   104329  1433127  69900   200  14392903
# 4    08.04.  -471827  0.5061  -934749   535317  69700   800  14780072
# ..      ...      ...     ...      ...      ...    ...   ...       ...
# 300  05.16. -3786158  0.5596  1856645  1875126  78200   100  20989778
# 301  05.14.  -393521  0.5600    64598   326338  78300   100  11763992
# 302  05.13.  -960230  0.5601 -1674382  2712543  78400   800  18652344
# 303  05.10.   618165  0.5602 -2037692  1400346  79200   500  16976124
# 304  05.09. -1232345  0.5601    24866  1046243  79700  1600  18759935
#
# [305 rows x 8 columns]

# %%
# 각 칼럼별 산포도 그래프
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(font="NanumGothic", rc={"axes.unicode_minus": False})

sns.pairplot(df)
plt.show()
